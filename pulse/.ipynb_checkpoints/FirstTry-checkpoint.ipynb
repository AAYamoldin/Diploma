# %%
import numpy as np
from typing import Tuple
import pandas as pd
import pickle
import scipy.special as sc
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def weighted_mse(u_exp: np.ndarray, u: np.ndarray, time: np.ndarray, eps: float = 0.0) -> Tuple[np.ndarray, np.ndarray]:
    dt = np.diff(time, n=1, axis=0)
    dt = np.append(dt, dt[-1])

    amplitude = np.dot(dt, u * u_exp) / np.dot(dt, u ** 2)
    e = (u_exp - amplitude * u) / (u_exp + eps) * dt

    loss = np.dot(e, e)
    return loss, amplitude

# %%
import pandas as pd
unpickled_df = pd.read_pickle('./decays.pickle')
unpickled_df.head()
# Out:
#                                          parameters   \
# 0  [{'sigma': 1435168.9390908787, 'mu': 89.058309...
# 0  [{'sigma': 6273819.790735516, 'mu': 76.4296341...
# 0  [{'sigma': 1185609.7405302143, 'mu': 145.77550...
# 0  [{'sigma': 6143423.656344486, 'mu': 71.4151574...
# 0  [{'sigma': 6366540.795349254, 'mu': 132.191461...
#
#                                                decay
# 0  [0.20414764740139812, 0.19512088018885956, 0.1...
# 0  [0.1853657500837078, 0.17325324056605024, 0.16...
# 0  [0.20965104452381175, 0.20151618304390082, 0.1...
# 0  [0.185046111522035, 0.1727535353636631, 0.1607...
# 0  [0.19235541864543546, 0.18131712610011289, 0.1...

# %%
print(unpickled_df['parameters '].iloc[0])
# Out:
# [{'sigma': 1435168.9390908787, 'mu': 89.05830983771534, 'd': 89, 'th': 2.8163372753619518, 'th0': 6.5}]

# %%
print(unpickled_df['decay'].iloc[1])
# Out:
# [0.1853657500837078, 0.17325324056605024, 0.16137984866188596, 0.14767274860043825, 0.14054205562862432, 0.13361570142891543, 0.12639660144562767, 0.11908495947679494, 0.11143253735935438, 0.10404788564780873, 0.09668797518510043, 0.08925031938061825, 0.0819507171399824, 0.07475427335260053, 0.06784322857876779, 0.06107588867842254, 0.054648738642522544, 0.04859256532767319, 0.04280150922879604, 0.03750183304472978, 0.03256403039915821, 0.028068486237626353, 0.023997861531996907, 0.020372859490138354, 0.017178950405200878, 0.014388781362204187, 0.01198151437694591, 0.009927036317937536, 0.008190160102682165, 0.006735065288610897, 0.005521719805841198, 0.004497360867676629, 0.0036323972009979573, 0.0028923348875184254, 0.0022594569817647983, 0.0017220296389554406, 0.0012746282194345104, 0.0009113270260187545, 0.0006260702353531296, 0.0004110038059525578, 0.0002561536898304886, 0.0001502377666809059, 8.210684334635793e-05, 4.135184559677432e-05, 1.890215339842355e-05, 7.727270437946536e-06]

# %%
def weighted_mse(u_exp: np.ndarray, u: np.ndarray, time: np.ndarray, eps: float = 0.0) -> Tuple[np.ndarray, np.ndarray]:
    dt = np.diff(time, n=1, axis=0)
    dt = np.append(dt, dt[-1])

    amplitude = np.dot(dt, u * u_exp) / np.dot(dt, u ** 2)
    e = (u_exp - amplitude * u) / (u_exp + eps) * dt

    loss = np.dot(e, e)
    return loss, amplitude


t = 1e-3 * np.array([
    0.135, 0.180, 0.235, 0.315, 0.365, 0.420,
    0.485, 0.560, 0.650, 0.750, 0.865, 1.000,
    1.155, 1.335, 1.540, 1.780, 2.055, 2.370,
    2.740, 3.160, 3.650, 4.215, 4.870, 5.625,
    6.495, 7.500, 8.660, 10.00, 11.55, 13.34,
    15.40, 17.79, 20.54, 23.72, 27.39, 31.63,
    36.52, 42.17, 48.70, 56.24, 64.94, 74.99,
    86.60, 100.0, 115.5, 133.4
])

# %%
unpickled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75200 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   parameters   75200 non-null  object
#  1   decay        75200 non-null  object
# dtypes: object(2)
# memory usage: 1.7+ MB

# %%
kek = unpickled_df['parameters '][0]
print(kek)
kek = unpickled_df['parameters '].iloc[40000]
print(kek)
kek[0].get('sigma')
# Out:
# 0    [{'sigma': 1435168.9390908787, 'mu': 89.058309...
# 0    [{'sigma': 6273819.790735516, 'mu': 76.4296341...
# 0    [{'sigma': 1185609.7405302143, 'mu': 145.77550...
# 0    [{'sigma': 6143423.656344486, 'mu': 71.4151574...
# 0    [{'sigma': 6366540.795349254, 'mu': 132.191461...
#                            ...
# 0    [{'sigma': 3762849.6012914125, 'mu': 148.81610...
# 0    [{'sigma': 2875169.70201072, 'mu': 42.34207174...
# 0    [{'sigma': 5574139.120522762, 'mu': 96.8725661...
# 0    [{'sigma': 1451156.4908713333, 'mu': 43.394390...
# 0    [{'sigma': 7901269.910883426, 'mu': 23.4973872...
# Name: parameters , Length: 75200, dtype: object
# [{'sigma': 8931973.876361609, 'mu': 31.717744380614917, 'd': 89, 'th': 4.805890865824528, 'th0': 6.5}]
# 8931973.876361609

# %% [markdown]
# ## Перенесём все данные в таблицу для удобства работы

# %%
d = []
for p in unpickled_df['parameters ']:
    d.append({'Sigma': p[0].get('sigma'), 'mu':p[0].get('mu'),
              'd':p[0].get('d'), 'th': p[0].get('th'),
              'th0':p[0].get('th0')})
decay = []
df = pd.DataFrame(d)
dec_df = []
for id, p in enumerate(unpickled_df['decay']):
    dec_df.append(p)
df['Decay'] = dec_df
df.head(10)
# Out:
#           Sigma          mu   d         th  th0  \
# 0  1.435169e+06   89.058310  89   2.816337  6.5
# 1  6.273820e+06   76.429634  89   9.039558  6.5
# 2  1.185610e+06  145.775506  89   3.942288  6.5
# 3  6.143424e+06   71.415157  89   7.672864  6.5
# 4  6.366541e+06  132.191462  89   4.341253  6.5
# 5  2.202663e+06   67.409757  89   3.684940  6.5
# 6  5.452385e+06   58.463764  89   4.742516  6.5
# 7  8.362600e+06   27.018713  89   1.604036  6.5
# 8  3.133573e+06  139.161563  89  10.772532  6.5
# 9  5.335198e+06   47.146775  89   8.921513  6.5
#
#                                                Decay
# 0  [0.20414764740139812, 0.19512088018885956, 0.1...
# 1  [0.1853657500837078, 0.17325324056605024, 0.16...
# 2  [0.20965104452381175, 0.20151618304390082, 0.1...
# 3  [0.185046111522035, 0.1727535353636631, 0.1607...
# 4  [0.19235541864543546, 0.18131712610011289, 0.1...
# 5  [0.19707648324855812, 0.18683864905413106, 0.1...
# 6  [0.18438771577303842, 0.17182722376412168, 0.1...
# 7  [0.1688063648017043, 0.15301738140312576, 0.13...
# 8  [0.20015195150516177, 0.19068437501823504, 0.1...
# 9  [0.18162651605649227, 0.16864305147554345, 0.1...

# %% [markdown]
# ## Постичитаем корреляцию между входными признаками th, sigma,mu

# %%
correlations_data = df.corr()
print(correlations_data)
# Out:
#           Sigma        mu   d        th  th0
# Sigma  1.000000  0.003973 NaN  0.002132  NaN
# mu     0.003973  1.000000 NaN -0.003228  NaN
# d           NaN       NaN NaN       NaN  NaN
# th     0.002132 -0.003228 NaN  1.000000  NaN
# th0         NaN       NaN NaN       NaN  NaN

# %% [markdown]
# ### Из полученных значений видно, что d и th0 можно убрать из анализируемых данных. Для всех остальных переменных корреляция мала, что говорит о том что эти признаки не избыточны и мы должны их влючить в анализ

# %%
tmp_data = pd.DataFrame()
tmp_data = df.copy()
#tmp_data['Outside_D_Fact'] = tmp_data['d'] - 2 * tmp_data['th0'] + 2 * tmp_data['th']
#del data['d']
#del data ['th0']
tmp_data.head()
# Out:
#           Sigma          mu   d        th  th0  \
# 0  1.435169e+06   89.058310  89  2.816337  6.5
# 1  6.273820e+06   76.429634  89  9.039558  6.5
# 2  1.185610e+06  145.775506  89  3.942288  6.5
# 3  6.143424e+06   71.415157  89  7.672864  6.5
# 4  6.366541e+06  132.191462  89  4.341253  6.5
#
#                                                Decay
# 0  [0.20414764740139812, 0.19512088018885956, 0.1...
# 1  [0.1853657500837078, 0.17325324056605024, 0.16...
# 2  [0.20965104452381175, 0.20151618304390082, 0.1...
# 3  [0.185046111522035, 0.1727535353636631, 0.1607...
# 4  [0.19235541864543546, 0.18131712610011289, 0.1...

# %%
# # Работающая ячейка, которая берет два случайных параметра
# # и считает функцию потерь между ними, а затем всё собирает в одну таблицу
# d = []
# while(len(tmp_data) >= 1):
#     kek = tmp_data.sample(2)
#     d.append({'Sigma1': kek.get('Sigma').iloc[0],
#               'Sigma2': kek.get('Sigma').iloc[1],
#               'mu1':kek.get('mu').iloc[0],
#               'mu2':kek.get('mu').iloc[1],
#               'th1':kek.get('th').iloc[0],
#               'th2':kek.get('th').iloc[1],
#               'loss':weighted_mse(np.array(kek.get('Decay').iloc[0]),np.array(kek.get('Decay').iloc[1]),t)[0]})
#     tmp_data = tmp_data.drop(index=kek.index[0])
#     tmp_data = tmp_data.drop(index=kek.index[1])
# data = pd.DataFrame(d)
# data.head()

# %% [markdown]
# ### Разобъем выборку на тестовую и обучающую с перемешиванием

# %%
from sklearn.model_selection import ShuffleSplit
rs = ShuffleSplit(n_splits=1, test_size=0.15, random_state=1, train_size=0.85)
print(rs.get_n_splits(tmp_data))
print(rs)
for train_index, test_index in rs.split(tmp_data):
    print("TRAIN:", train_index, "TEST:", test_index)
print("All len = ", len(tmp_data), " and len after splitting =", len(train_index) + len(test_index))
train_data = tmp_data.iloc[train_index].copy()
test_data = tmp_data.iloc[test_index].copy()
train_data
# Out:
# 1
# ShuffleSplit(n_splits=1, random_state=1, test_size=0.15, train_size=0.85)
# TRAIN: [19628  2486 64883 ... 73349 50057  5192] TEST: [15067 15441 53512 ... 17249 38159 67661]
# All len =  75200  and len after splitting = 75200
#               Sigma          mu   d         th  th0  \
# 19628  2.208994e+06   49.822443  89   2.721457  6.5
# 2486   4.145052e+06   89.330878  89   3.844767  6.5
# 64883  9.213975e+06   50.220776  89   6.476081  6.5
# 10027  9.713393e+06  133.763822  89   1.312150  6.5
# 51126  6.594258e+06   48.606896  89   5.393066  6.5
# ...             ...         ...  ..        ...  ...
# 20609  5.253770e+06   69.337570  89   8.079307  6.5
# 21440  7.013614e+06   18.160462  89  10.886509  6.5
# 73349  6.281616e+06   79.829317  89   1.861306  6.5
# 50057  6.611047e+06   47.219636  89   6.444066  6.5
# 5192   8.614585e+06   19.266376  89   5.230357  6.5
#
#                                                    Decay
# 19628  [0.19375629692752577, 0.18294351872284478, 0.1...
# 2486   [0.192993357268207, 0.1820247479384618, 0.1711...
# 64883  [0.1752133606610032, 0.16091191549296152, 0.14...
# 10027  [0.18759459262951242, 0.17560025481240513, 0.1...
# 51126  [0.17945400597800243, 0.1659367937378173, 0.15...
# ...                                                  ...
# 20609  [0.18670506995857652, 0.1747114005156804, 0.16...
# 21440  [0.16552623431106728, 0.14911657811994278, 0.1...
# 73349  [0.18664879988311645, 0.17448650105585312, 0.1...
# 50057  [0.17896371071292033, 0.16537861252358166, 0.1...
# 5192   [0.16389287245944764, 0.14698608433139554, 0.1...
#
# [63920 rows x 6 columns]

# %% [markdown]
# ### Отнормируем обучающую выборку и запомним параметры нормировки

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
print(scaler.fit(train_data.iloc[:,0:5]))
print(scaler.mean_)
means = scaler.mean_
print(scaler.scale_)
stds = scaler.scale_
train_data.iloc[:, 0:5] = scaler.transform(train_data.iloc[:, 0:5])
train_data
# Out:
# StandardScaler()
# [5.49793364e+06 8.00354882e+01 8.90000000e+01 6.18313815e+00
#  6.50000000e+00]
# [2.58728391e+06 4.04162034e+01 1.00000000e+00 3.19023924e+00
#  1.00000000e+00]
#           Sigma        mu    d        th  th0  \
# 19628 -1.271194 -0.747548  0.0 -1.085085  0.0
# 2486  -0.522897  0.229992  0.0 -0.732977  0.0
# 64883  1.436271 -0.737692  0.0  0.091825  0.0
# 10027  1.629299  1.329376  0.0 -1.526841  0.0
# 51126  0.423736 -0.777624  0.0 -0.247653  0.0
# ...         ...       ...  ...       ...  ...
# 20609 -0.094371 -0.264694  0.0  0.594366  0.0
# 21440  0.585819 -1.530946  0.0  1.474300  0.0
# 73349  0.302898 -0.005101  0.0 -1.354705  0.0
# 50057  0.430225 -0.811948  0.0  0.081789  0.0
# 5192   1.204603 -1.503583  0.0 -0.298655  0.0
#
#                                                    Decay
# 19628  [0.19375629692752577, 0.18294351872284478, 0.1...
# 2486   [0.192993357268207, 0.1820247479384618, 0.1711...
# 64883  [0.1752133606610032, 0.16091191549296152, 0.14...
# 10027  [0.18759459262951242, 0.17560025481240513, 0.1...
# 51126  [0.17945400597800243, 0.1659367937378173, 0.15...
# ...                                                  ...
# 20609  [0.18670506995857652, 0.1747114005156804, 0.16...
# 21440  [0.16552623431106728, 0.14911657811994278, 0.1...
# 73349  [0.18664879988311645, 0.17448650105585312, 0.1...
# 50057  [0.17896371071292033, 0.16537861252358166, 0.1...
# 5192   [0.16389287245944764, 0.14698608433139554, 0.1...
#
# [63920 rows x 6 columns]

# %% [markdown]
# ### По найденной дисперсии и среднему отнормируем тестовую выборку

# %%
test_data.iloc[:, 0:5] = scaler.transform(test_data.iloc[:, 0:5])
test_data
# Out:
#           Sigma        mu    d        th  th0  \
# 15067 -0.997694  0.239632  0.0 -1.224529  0.0
# 15441  0.702035  0.865774  0.0  1.501683  0.0
# 53512 -0.257575  1.301108  0.0  0.960704  0.0
# 55517 -0.439870 -0.182053  0.0  0.296815  0.0
# 18250  0.870267 -1.471396  0.0 -0.450235  0.0
# ...         ...       ...  ...       ...  ...
# 69892  0.814175  0.781662  0.0 -0.878862  0.0
# 72626 -0.020505 -0.181898  0.0 -0.651101  0.0
# 17249  0.133407  1.380844  0.0  0.863656  0.0
# 38159  1.210575 -0.099357  0.0  1.416446  0.0
# 67661  1.430852 -0.909071  0.0 -1.060979  0.0
#
#                                                    Decay
# 15067  [0.19710951874393856, 0.18686734402129945, 0.1...
# 15441  [0.18729061178144052, 0.17607316033246334, 0.1...
# 53512  [0.19492830118742754, 0.18461371393381612, 0.1...
# 55517  [0.18975509517206954, 0.17826619531626262, 0.1...
# 18250  [0.16612494686759216, 0.14972489038879724, 0.1...
# ...                                                  ...
# 69892  [0.1882601086365116, 0.17643418646482018, 0.16...
# 72626  [0.18716586487573802, 0.17512817120621807, 0.1...
# 17249  [0.1928662308439771, 0.18225947646392704, 0.17...
# 38159  [0.1803007929163741, 0.16759557921691812, 0.15...
# 67661  [0.17361789585296816, 0.15884240040603975, 0.1...
#
# [11280 rows x 6 columns]

# %% [markdown]
# ## PyTorch

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch
import torch.optim as optim
torch.backends.cudnn.enabled = False

# %% [markdown]
# ### convert pd.Dataframe to torch.tensor

# %%
def get_device():
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
    else:
        device = torch.device('cpu') # don't have GPU 
    return device

device = get_device()
print(device)

def convert_to_tensor(converting_data):
    d = []
    tmp_data = converting_data.copy()
    while(len(tmp_data) >= 1):
        kek = tmp_data.sample(2)
        d.append({'Sigma1': kek.get('Sigma').iloc[0],
                  'Sigma2': kek.get('Sigma').iloc[1],
                  'mu1':kek.get('mu').iloc[0],
                  'mu2':kek.get('mu').iloc[1],
                  'th1':kek.get('th').iloc[0],
                  'th2':kek.get('th').iloc[1],
                  'loss':weighted_mse(np.array(kek.get('Decay').iloc[0]),np.array(kek.get('Decay').iloc[1]),t)[0]})
        tmp_data = tmp_data.drop(index=kek.index[0])
        tmp_data = tmp_data.drop(index=kek.index[1])
    ex_data = pd.DataFrame(d)
    targets_tensor = torch.tensor(ex_data['loss'].values).to(device)
    features_tensor = torch.tensor(ex_data[['Sigma1','Sigma2','mu1','mu2','th1','th2']].values).to(device)
    tensor =  torch.tensor(ex_data[['Sigma1','Sigma2','mu1','mu2','th1','th2','loss']].values).to(device)
    return tensor, features_tensor, targets_tensor
# Out:
# cuda:0

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
train, train_features, train_targets = convert_to_tensor(train_data)
test, test_features, test_targets = convert_to_tensor(test_data)

# %%
trainset = torch.utils.data.DataLoader(train, batch_size=10, shuffle=True)
testset = torch.utils.data.DataLoader(train, batch_size=10, shuffle=True, drop_last=True)

# %% [markdown]
# ### Тело сети

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear (6, 32)
        self.fc2 = nn.Linear (32, 32)
        self.fc3 = nn.Linear (32, 32)
        self.fc4 = nn.Linear (32, 32)
        self.fc5 = nn.Linear (32, 1)
    
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.fc5(x)
        return F.linear(x,x)
        

net = Net().float().to(device)
loss_function = nn.L1Loss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# ### Запуск обучения по эпохам

# %%
epochs = 5
for epoch in range(epochs):
    for data in trainset:
        X = data [:, 0:-1]
        y = data[:,-1]
        net.zero_grad()
        output = net(X.float())
        loss = nn.L1Loss()(output, y)
        loss.backward()
        optimizer.step()
    print(loss)
# Out:
# /home/alexander/anaconda3/lib/python3.8/site-packages/torch/nn/modules/loss.py:94: UserWarning: Using a target size (torch.Size([10])) that is different to the input size (torch.Size([10, 10])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# tensor(3.3517e+14, device='cuda:0', dtype=torch.float64,
#        grad_fn=<L1LossBackward>)
# tensor(6.5554e+12, device='cuda:0', dtype=torch.float64,
#        grad_fn=<L1LossBackward>)
# tensor(1.4623e+13, device='cuda:0', dtype=torch.float64,
#        grad_fn=<L1LossBackward>)
# tensor(1.8558e+15, device='cuda:0', dtype=torch.float64,
#        grad_fn=<L1LossBackward>)
# tensor(4.6846e+14, device='cuda:0', dtype=torch.float64,
#        grad_fn=<L1LossBackward>)

# %% [markdown]
# ### Тестирование сети

# %%
for data in trainset:
    X = data [:, 0:-1]
    y = data[:,-1]
    output = net(X.float())
    print('This is X')
    print(X.float())
    print('This is Y')
    print(y)
    print('This is output')
    print(output)
    break
# Out:
# This is X
# tensor([[ 0.0295, -1.6679, -1.4036, -0.4612,  0.0501, -0.8562],
#         [ 1.0164,  0.5873, -0.5851,  0.0630, -1.6393,  0.5831],
#         [-0.1004,  0.9907,  0.9163, -0.7903,  1.5807, -0.2877],
#         [ 1.4766, -0.6970, -1.2346, -0.2744, -1.4124,  1.0403],
#         [ 1.3863,  0.4974,  0.8450, -0.1942, -0.4568,  0.9587],
#         [ 1.5308, -0.4462,  1.5225,  0.1887,  0.5655, -0.2796],
#         [ 1.0654, -0.5127, -1.3901, -0.7417, -0.8834, -0.1621],
#         [ 0.2598,  0.6964,  1.3530,  1.6116,  0.1336,  0.2355],
#         [ 0.2287,  0.3890, -1.2342, -1.5223, -1.6494,  1.0774],
#         [ 0.0646,  0.4797,  1.2571,  0.4128,  1.4934, -1.3125]],
#        device='cuda:0')
# This is Y
# tensor([1.5911e-03, 7.2898e+15, 1.2814e-03, 1.4212e+11, 1.0799e-01, 1.5048e-03,
#         1.5768e-03, 6.0536e-03, 3.0309e+14, 1.5651e-03], device='cuda:0',
#        dtype=torch.float64)
# This is output
# tensor([[3.6339e+08, 3.2810e+11, 4.0885e+08, 1.6056e+08, 2.3400e+08, 3.7490e+08,
#          2.2681e+08, 2.7956e+08, 6.5633e+11, 4.6478e+08],
#         [3.2810e+11, 2.9623e+14, 3.6914e+11, 1.4497e+11, 2.1128e+11, 3.3849e+11,
#          2.0479e+11, 2.5241e+11, 5.9258e+14, 4.1964e+11],
#         [4.0885e+08, 3.6914e+11, 4.6000e+08, 1.8065e+08, 2.6328e+08, 4.2180e+08,
#          2.5519e+08, 3.1453e+08, 7.3844e+11, 5.2292e+08],
#         [1.6056e+08, 1.4497e+11, 1.8065e+08, 7.0946e+07, 1.0339e+08, 1.6565e+08,
#          1.0022e+08, 1.2352e+08, 2.9000e+11, 2.0536e+08],
#         [2.3400e+08, 2.1128e+11, 2.6328e+08, 1.0339e+08, 1.5069e+08, 2.4142e+08,
#          1.4606e+08, 1.8002e+08, 4.2264e+11, 2.9929e+08],
#         [3.7490e+08, 3.3849e+11, 4.2180e+08, 1.6565e+08, 2.4142e+08, 3.8678e+08,
#          2.3400e+08, 2.8841e+08, 6.7712e+11, 4.7950e+08],
#         [2.2681e+08, 2.0479e+11, 2.5519e+08, 1.0022e+08, 1.4606e+08, 2.3400e+08,
#          1.4157e+08, 1.7449e+08, 4.0966e+11, 2.9010e+08],
#         [2.7956e+08, 2.5241e+11, 3.1453e+08, 1.2352e+08, 1.8002e+08, 2.8841e+08,
#          1.7449e+08, 2.1506e+08, 5.0492e+11, 3.5756e+08],
#         [6.5633e+11, 5.9258e+14, 7.3844e+11, 2.9000e+11, 4.2264e+11, 6.7712e+11,
#          4.0966e+11, 5.0492e+11, 1.1854e+15, 8.3945e+11],
#         [4.6478e+08, 4.1964e+11, 5.2292e+08, 2.0536e+08, 2.9929e+08, 4.7950e+08,
#          2.9010e+08, 3.5756e+08, 8.3945e+11, 5.9446e+08]], device='cuda:0',
#        grad_fn=<MmBackward>)
