# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme()
import sys
from common import tool_times
from common import well_construction as wc
from common.sensor_types import sensors
from solvers.solver_cim_py.interface import Solver
import torch
import plotly
import plotly.graph_objs as go
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
from typing import Tuple
import torch
import torch.optim as optim
from model import Net
model = torch.load('model_weights/modelentire.pth')
model.load_state_dict(torch.load('model_weights/model.pth'))
loss_function = nn.MSELoss()
model.eval()

def get_device():
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
    else:
        device = torch.device('cpu') # don't have GPU 
    return device

device = get_device()
net = model.double().to(device)

def weighted_mse(u_exp: np.ndarray, u: np.ndarray, time: np.ndarray, eps: float = + 10 ** (-15)) -> Tuple[np.ndarray, np.ndarray]:
    dt = np.diff(time, n=1, axis=0)
    dt = np.append(dt, dt[-1])
    amplitude = np.dot(dt, u * u_exp) / np.dot(dt, u ** 2)
    e = (u_exp - amplitude * u) / (u_exp + eps) * dt
    
    loss = np.dot(e, e)
    return loss



t = 1e-3 * np.array([
    0.135, 0.180, 0.235, 0.315, 0.365, 0.420,
    0.485, 0.560, 0.650, 0.750, 0.865, 1.000,
    1.155, 1.335, 1.540, 1.780, 2.055, 2.370,
    2.740, 3.160, 3.650, 4.215, 4.870, 5.625,
    6.495, 7.500, 8.660, 10.00, 11.55, 13.34,
    15.40, 17.79, 20.54, 23.72, 27.39, 31.63,
    36.52, 42.17, 48.70, 56.24, 64.94, 74.99,
    86.60, 100.0, 115.5, 133.4
])

df = pd.read_pickle('Dataset')
#fix_normed_vector = df.sample(1) временно
fix_normed_vector = df.loc[9030]
fix_normed_vector = pd.DataFrame(fix_normed_vector).transpose()
print ('Зафиксировали произвольный вектор из датафрейма с компонентами \n')
fix_normed_vector
# Out:
# Зафиксировали произвольный вектор из датафрейма с компонентами
#          Sigma       mu  d        th th0  \
# 9030 -0.809753 -1.56861  0 -0.248755   0
#
#                                                   Decay
# 9030  [0.17439216402987712, 0.15983478220067351, 0.1...

# %% [markdown]
# ## Считаем лосс (сигма, мю) через модельную функцию

# %% [markdown]
# ### Нахождение границ для оптимизатора с учетом параметров усреднения первоначальной выборки

# %%
means = np.fromfile('means_scaler')
print(means)
stds = np.fromfile('stds_scaler')
print(stds)
a = [[stds[0]]]
b = [[1e+06-means[0]]]
sigma_min = np.linalg.solve(a,b)
#print('Sigma lower bound',sigma_min)
a = [[stds[1]]]
b = [[10-means[1]]]
mu_min = np.linalg.solve(a,b)
#print ('mu lower bound', mu_min)
a = [[stds[3]]]
b = [[0.650209-means[3]]]
th_min = np.linalg.solve(a,b)
#print ('th lower bound', th_min)

a = [[stds[0]]]
b = [[10e+06-means[0]]]
sigma_max = np.linalg.solve(a,b)
#print('Sigma upper bound',sigma_max)
a = [[stds[1]]]
b = [[150-means[1]]]
mu_max = np.linalg.solve(a,b)
#print ('mu upper bound', mu_max)
a = [[stds[3]]]
b = [[11.7-means[3]]]
th_max = np.linalg.solve(a,b)
#print ('th upper bound', th_max)

#fix_real_vector = df.sample(1)
fix_real_vector = fix_normed_vector[['Sigma', 'mu', 'd', 'th', 'th0']]
fix_real_vector = fix_real_vector*stds+means
fix_real_vector['Decay'] = fix_normed_vector['Decay']
print ('Зафиксировали произвольный вектор из датафрейма с real компонентами \n')
fix_real_vector
# Out:
# [5.49793364e+06 8.00354882e+01 8.90000000e+01 6.18313815e+00
#  6.50000000e+00]
# [2.58728391e+06 4.04162034e+01 1.00000000e+00 3.19023924e+00
#  1.00000000e+00]
# Зафиксировали произвольный вектор из датафрейма с real компонентами
#             Sigma       mu   d       th  th0  \
# 9030  3.40287e+06  16.6383  89  5.38955  6.5
#
#                                                   Decay
# 9030  [0.17439216402987712, 0.15983478220067351, 0.1...

# %% [markdown]
# ### Подсчет и построение тепловых карт лосса с помощью нейросети и модельной функции

# %%
def model_decay(d=fix_real_vector.get('d').iloc[0], th0=fix_real_vector.get('th0').iloc[0],
                th=fix_real_vector.get('th').iloc[0], sigma=fix_real_vector.get('Sigma').iloc[0],
                mu=fix_real_vector.get('mu').iloc[0]):
    tubes = [
        wc.Tube(d=(d), th0=(th0), th=(th), sigma=(sigma), mu=(mu)),
    ]

    sensor = sensors.PULSE_3E_1
    times = tool_times.times[sensor]
    solver = Solver(sensor, times, tool_averaging=True, verbose=0)
    output = solver.get_curve(tubes)
    return(output)

def model_loss(real_sigma,real_mu):
    return np.log(weighted_mse(np.array(fix_real_vector.get('Decay').iloc[0]), np.array(model_decay(sigma=real_sigma,
                                                                             mu=real_mu)),t))
def net_loss(norm_sigma, norm_mu):
    tensor = torch.tensor([fix_normed_vector.get('Sigma').iloc[0],norm_sigma,
                           fix_normed_vector.get('mu').iloc[0],norm_mu,
                           fix_normed_vector.get('th').iloc[0],fix_normed_vector.get('th').iloc[0]])
    tensor = tensor.to(device)
    output = net(tensor.double())
    return (output.item())

def l2_norm(norm_sigma, norm_mu):
     return np.linalg.norm([fix_normed_vector.get('Sigma').iloc[0] - norm_sigma,
                          fix_normed_vector.get('mu').iloc[0] - norm_mu])

def model_minimization_function(variable_vector, constant=0.5):
    real_sigma = variable_vector[0]
    real_mu = variable_vector[1]
    norm_sigma = (real_sigma - means[0]) / stds[0]
    norm_mu = (real_mu - means[1]) / stds[1]
    return (-1 * l2_norm(norm_sigma, norm_mu) + constant * model_loss(real_sigma, real_mu))

# %% [markdown]
# #### Вычисление и построение карты model_loss and net_loss

# %%
from tqdm import tqdm
size = 30
sigma_real = np.linspace(1e-06, 2 * fix_real_vector.get('Sigma').iloc[0], num=size, retstep=True)#sigma
mu_real = np.linspace(1e-06, 2 * fix_real_vector.get('mu').iloc[0], num=size, retstep=True)#mu
i = 0
j = 0
loss_model = np.zeros((size,size))

for i in tqdm(range(size)):
    while (j < size):
        loss_model[i][j] = model_loss(sigma_real[0][j],mu_real[0][i])
        j = j + 1
    j = 0
loss_model = pd.DataFrame(loss_model)
loss_model.index = np.around(mu_real[0],1) 
loss_model.columns = np.around(sigma_real[0],3)
loss_model.to_pickle('./loss_model_model_matrix.pkl')
#loss_model = pd.read_pickle('./loss_model_model_matrix.pkl')
# Out:
#   0%|                                                                                           | 0/30 [00:00<?, ?it/s]2021-02-17 19:44:27 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:27 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:27 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:27 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:27 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:29 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:29 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:29 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:29 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:29 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:29 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=1e-06, mu=1e-06),]
# 2021-02-17 19:44:29 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:30 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:30 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:30 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:30 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:30 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:30 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:30 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:32 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:32 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:32 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:32 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:32 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:32 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=234680.7957412754, mu=1e-06),]
# 2021-02-17 19:44:32 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:33 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:33 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:33 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:33 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:33 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:33 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:33 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:35 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:35 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:35 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:35 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:35 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:35 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=469361.5914815508, mu=1e-06),]
# 2021-02-17 19:44:35 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:36 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:36 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:36 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:36 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:36 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:36 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:36 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:38 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:38 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:38 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:38 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:38 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:38 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=704042.3872218261, mu=1e-06),]
# 2021-02-17 19:44:38 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:39 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:39 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:39 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:39 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:39 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:39 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:39 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:40 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:41 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:41 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:41 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:41 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:41 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=938723.1829621015, mu=1e-06),]
# 2021-02-17 19:44:41 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:42 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:42 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:42 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:42 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:42 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:42 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:42 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:44 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:44 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:44 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:44 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:44 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:44 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=1173403.9787023768, mu=1e-06),]
# 2021-02-17 19:44:44 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:45 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:45 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:45 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:45 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:45 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:45 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:45 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:47 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:47 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:47 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:47 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:47 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:47 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=1408084.7744426522, mu=1e-06),]
# 2021-02-17 19:44:47 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:48 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:48 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:48 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:48 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:48 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:48 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:48 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:50 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:50 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:50 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:50 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:50 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:50 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=1642765.5701829277, mu=1e-06),]
# 2021-02-17 19:44:50 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:52 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:52 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:52 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:52 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:52 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:52 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:52 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:53 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:53 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:53 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:53 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:53 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:53 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=1877446.365923203, mu=1e-06),]
# 2021-02-17 19:44:53 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:55 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:55 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:55 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:55 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:55 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:55 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:55 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:57 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:57 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:57 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:57 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:57 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:57 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=2112127.1616634782, mu=1e-06),]
# 2021-02-17 19:44:57 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:44:58 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:44:58 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:44:58 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:44:58 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:44:58 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:44:58 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:44:58 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:00 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:00 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:00 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:00 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:00 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:00 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=2346807.9574037534, mu=1e-06),]
# 2021-02-17 19:45:00 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:02 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:02 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:02 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:02 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:02 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:02 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:02 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:04 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:04 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:04 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:04 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:04 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:04 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=2581488.753144029, mu=1e-06),]
# 2021-02-17 19:45:04 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:05 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:05 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:05 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:05 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:05 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:05 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:05 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:07 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:07 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:07 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:07 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:07 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:07 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=2816169.5488843042, mu=1e-06),]
# 2021-02-17 19:45:07 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:09 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:09 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:09 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:09 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:09 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:09 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:09 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:11 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:11 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:11 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:11 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:11 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:11 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3050850.34462458, mu=1e-06),]
# 2021-02-17 19:45:11 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:13 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:13 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:13 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:13 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:13 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:13 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:13 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:15 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:15 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:15 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:15 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:15 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:15 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3285531.140364855, mu=1e-06),]
# 2021-02-17 19:45:15 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:16 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:16 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:16 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:16 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:16 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:16 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:16 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:18 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:18 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:18 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:18 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:18 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:18 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3520211.9361051307, mu=1e-06),]
# 2021-02-17 19:45:18 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:20 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:20 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:20 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:20 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:20 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:20 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:20 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:21 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:21 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:21 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:21 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:21 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:21 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3754892.731845406, mu=1e-06),]
# 2021-02-17 19:45:21 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:22 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:22 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:22 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:22 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:22 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:22 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:22 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:24 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:24 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:24 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:24 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:24 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:24 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3989573.527585681, mu=1e-06),]
# 2021-02-17 19:45:24 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:25 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:25 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:25 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:25 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:25 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:25 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:25 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:27 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:27 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:27 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:27 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:27 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:27 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=4224254.323325957, mu=1e-06),]
# 2021-02-17 19:45:27 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:28 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:28 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:28 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:28 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:28 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:28 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:28 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:30 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:30 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:30 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:30 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:30 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:30 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=4458935.119066233, mu=1e-06),]
# 2021-02-17 19:45:30 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:31 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:31 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:31 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:31 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:31 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:31 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:31 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:33 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:33 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:33 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:33 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:33 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:33 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=4693615.9148065075, mu=1e-06),]
# 2021-02-17 19:45:33 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:34 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:34 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:34 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:34 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:34 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:34 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:34 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:36 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:36 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:36 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:36 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:36 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:36 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=4928296.710546783, mu=1e-06),]
# 2021-02-17 19:45:36 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:37 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:37 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:37 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:37 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:37 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:37 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:37 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:38 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:39 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:39 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:39 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:39 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:39 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=5162977.506287059, mu=1e-06),]
# 2021-02-17 19:45:39 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:40 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:40 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:40 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:40 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:40 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:40 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:40 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:41 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:41 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:41 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:41 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:41 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:41 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=5397658.302027334, mu=1e-06),]
# 2021-02-17 19:45:41 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:44 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:44 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:44 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:44 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:44 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:44 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:44 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:46 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:46 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:46 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:46 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:46 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:46 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=5632339.097767609, mu=1e-06),]
# 2021-02-17 19:45:46 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:47 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:47 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:47 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:47 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:47 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:47 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:47 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:49 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:49 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:49 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:49 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:49 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:49 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=5867019.893507885, mu=1e-06),]
# 2021-02-17 19:45:49 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:52 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:52 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:52 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:52 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:52 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:52 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:52 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:53 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:53 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:53 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:53 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:53 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:53 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=6101700.68924816, mu=1e-06),]
# 2021-02-17 19:45:53 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:55 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:55 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:55 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:55 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:55 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:55 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:55 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:57 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:57 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:57 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:57 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:57 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:57 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=6336381.484988435, mu=1e-06),]
# 2021-02-17 19:45:57 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:45:58 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:45:58 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 19:45:58 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 19:45:58 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 19:45:58 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 19:45:58 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 19:45:58 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 19:46:00 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 19:46:00 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# ...
# 2021-02-17 20:29:23 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:23 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=4693615.9148065075, mu=33.276579866138206),]
# 2021-02-17 20:29:23 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:24 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:24 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:24 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:24 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:24 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:24 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 20:29:24 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:26 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:26 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:26 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:26 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:26 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:26 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=4928296.710546783, mu=33.276579866138206),]
# 2021-02-17 20:29:26 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:27 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:27 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:27 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:27 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:27 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:27 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 20:29:27 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:28 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:28 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:28 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:28 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:28 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:28 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=5162977.506287059, mu=33.276579866138206),]
# 2021-02-17 20:29:28 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:30 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:30 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:30 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:30 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:30 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:30 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 20:29:30 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:31 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:31 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:31 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:31 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:31 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:31 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=5397658.302027334, mu=33.276579866138206),]
# 2021-02-17 20:29:31 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:33 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:33 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:33 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:33 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:33 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:33 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 20:29:33 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:34 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:34 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:34 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:34 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:34 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:34 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=5632339.097767609, mu=33.276579866138206),]
# 2021-02-17 20:29:34 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:35 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:35 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:35 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:35 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:35 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:35 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 20:29:35 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:37 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:37 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:37 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:37 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:37 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:37 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=5867019.893507885, mu=33.276579866138206),]
# 2021-02-17 20:29:37 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:38 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:38 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:38 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:38 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:38 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:38 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 20:29:38 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:40 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:40 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:40 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:40 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:40 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:40 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=6101700.68924816, mu=33.276579866138206),]
# 2021-02-17 20:29:40 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:41 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:41 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:41 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:41 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:41 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:41 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 20:29:41 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:43 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:43 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:43 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:43 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:43 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:43 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=6336381.484988435, mu=33.276579866138206),]
# 2021-02-17 20:29:43 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:44 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:44 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:44 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:44 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:44 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:44 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 20:29:44 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:45 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:45 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:45 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:45 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:45 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:45 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=6571062.280728711, mu=33.276579866138206),]
# 2021-02-17 20:29:45 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:47 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:47 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:47 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:47 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:47 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:47 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=3402871.538234493, mu=16.638289933069103),]
# 2021-02-17 20:29:47 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:48 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:48 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 2021-02-17 20:29:48 INFO    : multi-lu-coil-modelling, (interface.py      :23  ) - Using cim-triangular solver
# 2021-02-17 20:29:48 INFO    : multi-lu-coil-modelling, (abstractsolver.py :100 ) - Solver validation ... complete
# 2021-02-17 20:29:48 INFO    : multi-lu-coil-modelling, (abstractsolver.py :93  ) - Tubes validation ... complete
# 2021-02-17 20:29:48 INFO    : multi-lu-coil-modelling, (interface.py      :140 ) - Received tubes:[
# 	Tube(id='', d=89.0, th=5.389551505199457, th0=6.5, sigma=6805743.076468986, mu=33.276579866138206),]
# 2021-02-17 20:29:48 INFO    : multi-lu-coil-modelling, (interface.py      :144 ) - Mesh loading ... complete
# 2021-02-17 20:29:50 INFO    : multi-lu-coil-modelling, (interface.py      :114 ) - Modelling tool averaging
# 2021-02-17 20:29:50 INFO    : multi-lu-coil-modelling, (interface.py      :172 ) - Done
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [45:22<00:00, 90.74s/it]

# %%
loss_model = pd.read_pickle('./loss_model_model_matrix.pkl')

# %%
i = 0
j = 0
loss_net = np.zeros((size, size))
sigma_norm = (sigma_real[0] - means[0]) / stds[0] 
mu_norm = (mu_real[0] - means[1]) / stds[1]

for i in tqdm(range(size)):
    while (j < size):
        loss_net[i][j] = net_loss(sigma_norm[j], mu_norm[i])
        j += 1
    j = 0
loss_net = pd.DataFrame(loss_net)
loss_net.index = np.around(mu_real[0],1) 
loss_net.columns = np.around(sigma_real[0],3)
loss_net.to_pickle('./loss_net_model_matrix.pkl')
#loss_net = pd.read_pickle('./loss_net_model_matrix.pkl')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 63.21it/s]

# %%
loss_net = pd.read_pickle('./loss_net_model_matrix.pkl')

# %% [markdown]
# #### Разница результатов классического и нейросетевого подхода

# %%
diff = abs(loss_model - loss_net)
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(diff, annot=False, vmin=0)
#name = 'log( loss( (' + str(fix_vector.get('mu').iloc[0])+ ', (' + str(fix_vector.get('Sigma').iloc[0]) + ')))'
name = "difference between model and net"
ax.set(xlabel='sigma', ylabel='mu', title=name)
# ax = f.gca()
# circle1 = plt.Circle((size/2,size/2), 0.5, color='g', fill=False, label="The zone of the fix vector")
# ax.add_patch(circle1)
# ax.legend()
f.savefig(name + '.png', bbox_inches='tight')

# %% [markdown]
# #### Тепловая карта спадов модельных данных и нейросети

# %%
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(loss_model, annot=False, vmax=5, vmin=-10)
name = "Logarifm of model loss"
ax.set(xlabel='sigma', ylabel='mu', title=name)
f.savefig(name + '.png', bbox_inches='tight')

# %%
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(loss_net, annot=False, vmax=5, vmin=-10)
name = "Logarifm of net loss"
ax.set(xlabel='sigma', ylabel='mu', title=name)
f.savefig(name + '.png', bbox_inches='tight')

# %% [markdown]
# ### Подсчет и построение тепловой карты л2 нормы

# %%
l2 = np.zeros((size, size))
i = 0
j = 0
for i in tqdm(range(size)):
    while (j < size):
        l2[i][j] = l2_norm(sigma_norm[j], mu_norm[i])
        j += 1
    j = 0
l2 = pd.DataFrame(l2)
l2.index = np.around(mu_real[0],1) 
l2.columns = np.around(sigma_real[0],3)
l2.to_pickle('./l2_matrix.pkl')
#l2 = pd.read_pickle('./l2_matrix.pkl')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 30/30 [00:00<00:00, 834.76it/s]

# %%
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(l2, annot=False)
name = "L2 between vectors"
ax.set(xlabel='sigma', ylabel='mu', title=name)
f.savefig(name + '.png', bbox_inches='tight')

# %% [markdown]
# ### Взвешенная сумма -l2_norm + constant * loss_model

# %%
constant = 50
weighted_sum = -l2 + constant * loss_model
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(weighted_sum, annot=False, vmin=-7, vmax=7)
name = "weighted sum with model_loss, constant = " + str(constant)
ax.set(xlabel='sigma', ylabel='mu', title=name)
f.savefig(name + '.png', bbox_inches='tight')

# %% [markdown]
# ### Оптимизация model_minimization_function

# %%
from scipy.optimize import minimize
minimize_result_data = []
constant = np.linspace(0.1,100,20)
for const in tqdm(constant):
    def model_minimization_function(variable_vector, constant=const):
        real_sigma = variable_vector[0]
        real_mu = variable_vector[1]
        norm_sigma = (real_sigma - means[0]) / stds[0]
        norm_mu = (real_mu - means[1]) / stds[1]
        return (-1 * l2_norm(norm_sigma, norm_mu) + constant * model_loss(real_sigma, real_mu))   
    x0 = np.array([fix_real_vector.get('Sigma').iloc[0],fix_real_vector.get('mu').iloc[0]])
    res =  minimize(model_minimization_function, x0, method='SLSQP', bounds=((sigma_min[0][0] * stds[0] + means[0], 
                                                                    sigma_max[0][0] * stds[0] + means[0]),
                                                                   (mu_min[0][0] * stds[1] + means[1],
                                                                    mu_max[0][0] * stds[1] + means[1])),options={'disp': False,
                                                                                                                'maxiter':1e6,
                                                                                                                'ftol':1e-9,
                                                                                                                'eps': 0.1})
    minimize_result_data.append({'l2_norm': l2_norm((res.x[0] - means[0]) / stds[0], (res.x[1] - means[1]) / stds[1]),
                                 'log_loss': model_loss(res.x[0], res.x[1]),
                                 'loss': np.exp(model_loss(res.x[0], res.x[1])),
                                 'constant': const, 'data': res.x, 'message': res.message})
minimize_result_data = pd.DataFrame(minimize_result_data)
minimize_result_data
#print(res)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [31:02<00:00, 93.12s/it]
#      l2_norm   log_loss          loss    constant  \
# 0   0.001445 -12.092935  5.598929e-06    0.100000
# 1   0.008578 -13.715137  1.105584e-06    5.357895
# 2   0.001251 -13.904963  9.144320e-07   10.615789
# 3   0.016749 -10.381791  3.099172e-05   15.873684
# 4   0.006401 -11.680591  8.456365e-06   21.131579
# 5   0.001129 -13.992772  8.375612e-07   26.389474
# 6   0.007564 -11.732122  8.031639e-06   31.647368
# 7   0.004540 -15.082367  2.817158e-07   36.905263
# 8   0.006026 -12.197417  5.043467e-06   42.163158
# 9   0.021337 -11.914815  6.690546e-06   47.421053
# 10  0.030476 -11.409059  1.109452e-05   52.678947
# 11  0.000007 -15.462990  1.925346e-07   57.936842
# 12  0.014375 -11.932519  6.573138e-06   63.194737
# 13  0.001979 -12.604746  3.356051e-06   68.452632
# 14  0.015546 -11.469767  1.044103e-05   73.710526
# 15  0.020618 -12.292625  4.585437e-06   78.968421
# 16  0.022504 -11.368633  1.155222e-05   84.226316
# 17  0.009408 -10.417170  2.991443e-05   89.484211
# 18  0.019022 -11.373746  1.149330e-05   94.742105
# 19  0.009565 -12.505771  3.705207e-06  100.000000
#
#                                         data  \
# 0    [3402871.5312198224, 16.57988244895581]
# 1     [3402871.748687675, 16.29159948160043]
# 2     [3402871.61646052, 16.587737206537668]
# 3    [3402863.171315271, 17.315218712523958]
# 4   [3402857.8642592854, 16.896991039116983]
# 5   [3402871.6054627756, 16.592645529907227]
# 6   [3402824.9665660528, 16.944008592947444]
# 7   [3402871.8385504363, 16.454818164785774]
# 8     [3402873.6665881984, 16.3947263935244]
# 9      [3402876.786525993, 15.7759444424857]
# 10   [3402875.627241426, 15.406557040929307]
# 11   [3402871.5369654726, 16.63855331765434]
# 12   [3402865.334306929, 17.219282197495016]
# 13   [3402858.0779818767, 16.71827655639753]
# 14  [3402854.5756022814, 17.266581487540236]
# 15   [3402874.398882302, 15.805000365948205]
# 16   [3402818.059119971, 17.547807769483306]
# 17  [3402872.3100557122, 16.258055816644717]
# 18   [3402865.497652741, 15.869485146175007]
# 19    [3402864.57353301, 17.024885997330493]
#
#                                  message
# 0   Optimization terminated successfully
# 1   Optimization terminated successfully
# 2   Optimization terminated successfully
# 3   Optimization terminated successfully
# 4   Optimization terminated successfully
# 5   Optimization terminated successfully
# 6   Optimization terminated successfully
# 7   Optimization terminated successfully
# 8   Optimization terminated successfully
# 9   Optimization terminated successfully
# 10  Optimization terminated successfully
# 11  Optimization terminated successfully
# 12  Optimization terminated successfully
# 13  Optimization terminated successfully
# 14  Optimization terminated successfully
# 15  Optimization terminated successfully
# 16  Optimization terminated successfully
# 17  Optimization terminated successfully
# 18  Optimization terminated successfully
# 19  Optimization terminated successfully

# %%
from scipy.optimize import minimize
minimize_result_data = []
constant = np.linspace(0.1,1,20)
for const in tqdm(constant):
    def model_minimization_function(variable_vector, constant=const):
        real_sigma = variable_vector[0]
        real_mu = variable_vector[1]
        norm_sigma = (real_sigma - means[0]) / stds[0]
        norm_mu = (real_mu - means[1]) / stds[1]
        return (-1 * l2_norm(norm_sigma, norm_mu) + constant * model_loss(real_sigma, real_mu))   
    x0 = np.array([fix_real_vector.get('Sigma').iloc[0],fix_real_vector.get('mu').iloc[0]])
    res =  minimize(model_minimization_function, x0, method='SLSQP', bounds=((sigma_min[0][0] * stds[0] + means[0], 
                                                                    sigma_max[0][0] * stds[0] + means[0]),
                                                                   (mu_min[0][0] * stds[1] + means[1],
                                                                    mu_max[0][0] * stds[1] + means[1])),options={'disp': False,
                                                                                                                'maxiter':1e6,
                                                                                                                'ftol':1e-9,
                                                                                                                'eps': 0.1})
    minimize_result_data.append({'l2_norm': l2_norm((res.x[0] - means[0]) / stds[0], (res.x[1] - means[1]) / stds[1]),
                                 'log_loss': model_loss(res.x[0], res.x[1]),
                                 'loss': np.exp(model_loss(res.x[0], res.x[1])),
                                 'constant': const, 'data': res.x, 'message': res.message})
minimize_result_data_2 = pd.DataFrame(minimize_result_data)
minimize_result_data_2
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [29:40<00:00, 89.02s/it]
#      l2_norm   log_loss          loss  constant  \
# 0   0.001445 -12.092935  5.598929e-06  0.100000
# 1   0.000866 -16.376645  7.721709e-08  0.147368
# 2   0.006677 -12.265871  4.709774e-06  0.194737
# 3   0.000035 -15.058342  2.885660e-07  0.242105
# 4   0.009851 -13.266574  1.731411e-06  0.289474
# 5   0.005816 -14.920616  3.311761e-07  0.336842
# 6   0.000205 -13.739127  1.079376e-06  0.384211
# 7   0.025151 -11.665635  8.583794e-06  0.431579
# 8   0.000010 -10.268471  3.471042e-05  0.478947
# 9   0.002110 -13.488713  1.386521e-06  0.526316
# 10  0.019121 -11.323671  1.208348e-05  0.573684
# 11  0.007256 -11.420569  1.096756e-05  0.621053
# 12  0.000394 -12.967655  2.334635e-06  0.668421
# 13  0.003909 -15.387541  2.076232e-07  0.715789
# 14  0.000535 -15.678152  1.552619e-07  0.763158
# 15  0.001427  -9.741754  5.877734e-05  0.810526
# 16  0.004414 -14.313456  6.077779e-07  0.857895
# 17  0.012103 -13.256091  1.749656e-06  0.905263
# 18  0.000016 -13.901714  9.174073e-07  0.952632
# 19  0.015210 -10.173103  3.818367e-05  1.000000
#
#                                         data  \
# 0    [3402871.5312198224, 16.57988244895581]
# 1     [3402870.988167426, 16.60330795495225]
# 2   [3402872.3912530644, 16.368449275498914]
# 3   [3402871.5380761013, 16.636878465589366]
# 4    [3402870.655915177, 16.240130795530145]
# 5    [3402871.572237833, 16.403221328689764]
# 6    [3402870.881289897, 16.646559483359198]
# 7    [3402873.335919962, 15.621764354558486]
# 8   [3402871.5375862094, 16.637874924408166]
# 9   [3402871.4222698957, 16.723583083926307]
# 10  [3402872.8007618603, 15.865505408427671]
# 11   [3402870.6928047985, 16.34504124740486]
# 12    [3402871.516786918, 16.62235555173673]
# 13  [3402870.8248983966, 16.480322957451964]
# 14    [3402871.531996856, 16.61665397369897]
# 15  [3402871.5557450177, 16.580627239412184]
# 16   [3402871.4357195944, 16.45991201021603]
# 17  [3402872.0170970983, 16.149138414324657]
# 18  [3402871.5385344196, 16.637657321735833]
# 19  [3402872.5500952117, 16.023573292697556]
#
#                                  message
# 0   Optimization terminated successfully
# 1   Optimization terminated successfully
# 2   Optimization terminated successfully
# 3   Optimization terminated successfully
# 4   Optimization terminated successfully
# 5   Optimization terminated successfully
# 6   Optimization terminated successfully
# 7   Optimization terminated successfully
# 8   Optimization terminated successfully
# 9   Optimization terminated successfully
# 10  Optimization terminated successfully
# 11  Optimization terminated successfully
# 12  Optimization terminated successfully
# 13  Optimization terminated successfully
# 14  Optimization terminated successfully
# 15  Optimization terminated successfully
# 16  Optimization terminated successfully
# 17  Optimization terminated successfully
# 18  Optimization terminated successfully
# 19  Optimization terminated successfully

# %%
from scipy.optimize import minimize
minimize_result_data = []
constant = np.linspace(0.1,1,20)
for const in tqdm(constant):
    def model_minimization_function(variable_vector, constant=const):
        real_sigma = variable_vector[0]
        real_mu = variable_vector[1]
        norm_sigma = (real_sigma - means[0]) / stds[0]
        norm_mu = (real_mu - means[1]) / stds[1]
        return (-1 * l2_norm(norm_sigma, norm_mu) + constant * model_loss(real_sigma, real_mu))   
    x0 = np.array([fix_real_vector.get('Sigma').iloc[0],fix_real_vector.get('mu').iloc[0]])
    res =  minimize(model_minimization_function, x0, method='SLSQP', bounds=((sigma_min[0][0] * stds[0] + means[0], 
                                                                    sigma_max[0][0] * stds[0] + means[0]),
                                                                   (mu_min[0][0] * stds[1] + means[1],
                                                                    mu_max[0][0] * stds[1] + means[1])),options={'disp': False,
                                                                                                                'maxiter':1e6,
                                                                                                                'ftol':1e-9,
                                                                                                                'eps': 1e-05})
    minimize_result_data.append({'l2_norm': l2_norm((res.x[0] - means[0]) / stds[0], (res.x[1] - means[1]) / stds[1]),
                                 'log_loss': model_loss(res.x[0], res.x[1]),
                                 'loss': np.exp(model_loss(res.x[0], res.x[1])),
                                 'constant': const, 'data': res.x, 'message': res.message})
minimize_result_data_3 = pd.DataFrame(minimize_result_data)
minimize_result_data_3
# Out:
#   0%|                                                                                           | 0/20 [00:00<?, ?it/s]
