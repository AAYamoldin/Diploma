# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('decays.pickle')
df
# Out:
#                                           parameters   \
# 0   [{'sigma': 1435168.9390908787, 'mu': 89.058309...
# 0   [{'sigma': 6273819.790735516, 'mu': 76.4296341...
# 0   [{'sigma': 1185609.7405302143, 'mu': 145.77550...
# 0   [{'sigma': 6143423.656344486, 'mu': 71.4151574...
# 0   [{'sigma': 6366540.795349254, 'mu': 132.191461...
# ..                                                ...
# 0   [{'sigma': 3762849.6012914125, 'mu': 148.81610...
# 0   [{'sigma': 2875169.70201072, 'mu': 42.34207174...
# 0   [{'sigma': 5574139.120522762, 'mu': 96.8725661...
# 0   [{'sigma': 1451156.4908713333, 'mu': 43.394390...
# 0   [{'sigma': 7901269.910883426, 'mu': 23.4973872...
#
#                                                 decay
# 0   [0.20414764740139812, 0.19512088018885956, 0.1...
# 0   [0.1853657500837078, 0.17325324056605024, 0.16...
# 0   [0.20965104452381175, 0.20151618304390082, 0.1...
# 0   [0.185046111522035, 0.1727535353636631, 0.1607...
# 0   [0.19235541864543546, 0.18131712610011289, 0.1...
# ..                                                ...
# 0   [0.1989342079087614, 0.18927252899300337, 0.17...
# 0   [0.18829436666029847, 0.17656272810881046, 0.1...
# 0   [0.19007882991699215, 0.17870545595082643, 0.1...
# 0   [0.19693454243996014, 0.1866965644316154, 0.17...
# 0   [0.1675783594832702, 0.15150731540552798, 0.13...
#
# [75200 rows x 2 columns]

# %%
from loss import t
i = np.random.randint(0, len(df))
plt.figure()
plt.semilogy(t, df['decay'].iloc[i])
print(df['parameters '].iloc[i])
# Out:
# [{'sigma': 4142321.6060819617, 'mu': 83.61237578037765, 'd': 89, 'th': 2.883499240130683, 'th0': 6.5}]

# %%
# !pip freeze
# Out:
# amqp==2.6.1
# appdirs==1.4.4
# argon2-cffi==20.1.0
# async-generator==1.10
# attrs==20.2.0
# backcall==0.2.0
# backports.functools-lru-cache==1.6.1
# billiard==3.6.3.0
# bleach==3.2.1
# certifi==2020.6.20
# cffi==1.14.0
# chardet==3.0.4
# click==7.1.2
# colorama==0.4.3
# conda==4.8.5
# conda-package-handling==1.7.0
# cryptography==2.9.2
# cycler==0.10.0
# decorator==4.4.2
# defusedxml==0.6.0
# entrypoints==0.3
# humanize==2.6.0
# idna==2.9
# importlib-metadata==1.7.0
# ipykernel==5.3.4
# ipython==7.18.1
# ipython-genutils==0.2.0
# jedi==0.17.2
# Jinja2==2.11.2
# json5==0.9.5
# jsonschema==3.2.0
# jupyter-client==6.1.7
# jupyter-core==4.6.3
# jupyterlab==2.2.8
# jupyterlab-pygments==0.1.1
# jupyterlab-server==1.2.0
# kiwisolver==1.2.0
# kombu==4.6.11
# MarkupSafe==1.1.1
# mccabe==0.6.1
# menuinst==1.4.16
# mistune==0.8.4
# mypy-extensions==0.4.3
# nbclient==0.5.0
# nbconvert==6.0.5
# nbformat==5.0.7
# nest-asyncio==1.4.0
# notebook==6.1.4
# packaging==20.4
# pandocfilters==1.4.2
# parso==0.7.1
# pathspec==0.8.0
# pickleshare==0.7.5
# prometheus-client==0.8.0
# prompt-toolkit==3.0.7
# pycodestyle==2.6.0
# pycosat==0.6.3
# pycparser==2.20
# pyflakes==2.2.0
# Pygments==2.7.1
# pyOpenSSL==19.1.0
# pyparsing==2.4.7
# pyrsistent==0.17.3
# PySocks==1.7.1
# python-dateutil==2.8.1
# pytz==2020.1
# pywin32==228
# pywinpty==0.5.7
# pyzmq==19.0.2
# regex==2020.7.14
# requests==2.24.0
# ruamel-yaml==0.15.87
# Send2Trash==1.5.0
# six==1.14.0
# terminado==0.9.1
# testpath==0.4.4
# toml==0.10.1
# tornado==6.0.4
# tqdm==4.46.0
# traitlets==5.0.4
# typed-ast==1.4.1
# typing-extensions==3.7.4.3
# urllib3==1.25.8
# vine==1.3.0
# wcwidth==0.2.5
# webencodings==0.5.1
# win-inet-pton==1.1.0
# wincertstore==0.2
# zipp==3.1.0
